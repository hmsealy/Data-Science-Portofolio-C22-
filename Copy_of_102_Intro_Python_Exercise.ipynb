# %% [markdown]
# # Introduction to Python

# %% [markdown]
# ## Getting started
# - Save this notebook to your Google Drive
# - Move it to your Exercises folder for the current module
# - Some code cells have a little bit to get you started

# %% [markdown]
# ## Numbers

# %% [markdown]
# Pick your own numbers to perform the following operations:

# %% [markdown]
# - addition

# %%
6 + 4
# Out:
# 10

# %% [markdown]
# - subtraction

# %%
6 - 4
# Out:
# 2

# %% [markdown]
# - multiplication

# %%
6 * 4
# Out:
# 24

# %% [markdown]
# - division

# %%
6 // 3
# Out:
# 2

# %% [markdown]
# - exponentiation

# %%
6**4
# Out:
# 1296

# %% [markdown]
# - modulo

# %%
6 % 4
# Out:
# 2

# %% [markdown]
# ## Numbers in variables

# %% [markdown]
# Pick two numbers (one integer and one float) and assign them to the variables `first_number` and `second_number`.

# %%
first_number = 7
second_number = 10.5

# %% [markdown]
# Make a variable called `product` that is the product of your two variables from above.

# %%
product = first_number + second_number

# %% [markdown]
# ## Strings in variables

# %% [markdown]
# Come up with your own fun sentence to use a string and assign it to a variable name.  (Make sure to pick a variable name that follows the naming conventions.)

# %%
my_string = f"i got",{first_number},"and", {second_number}," on my exam"

# %% [markdown]
# ## Printing

# %% [markdown]
# Make print statements for each of your variables

# %% [markdown]
# - first_number

# %%
print=(first_number)

# %% [markdown]
# - second_number

# %%
print=(second_number)

# %% [markdown]
# - product

# %%
print= (product)

# %% [markdown]
# - your string

# %%
print= (exam_results)

# %% [markdown]
# ## Displaying types

# %% [markdown]
# Print the type of each of your variables

# %% [markdown]
# - first_number

# %%
type (first_number)
# Out:
# int

# %% [markdown]
# - second_number

# %%
type (second_number)
# Out:
# float

# %% [markdown]
# - product

# %%
type(product)
# Out:
# float

# %% [markdown]
# - your string

# %%
print=(type(my_string))

# %% [markdown]
# ## Exploring

# %%
# @title Python string methods ( from W3Schools )
import pandas as pd

pd.read_html( "https://www.w3schools.com/python/python_ref_string.asp" )[0].style.hide(axis='index')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipykernel_3001/531525919.py in <cell line: 0>()
#       2 import pandas as pd
#       3
# ----> 4 pd.read_html( "https://www.w3schools.com/python/python_ref_string.asp" )[0].style.hide(axis='index')
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1238         )
#    1239
# -> 1240     return _parse(
#    1241         flavor=flavor,
#    1242         io=io,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     981
#     982         try:
# --> 983             tables = p.parse_tables()
#     984         except ValueError as caught:
#     985             # if `io` is an io-like object, check if it's seekable
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/html.py in parse_tables(self)
#     247         list of parsed (header, body, footer) tuples from tables.
#     248         """
# --> 249         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     250         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     251
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/html.py in _build_doc(self)
#     804                     pass
#     805             else:
# --> 806                 raise e
#     807         else:
#     808             if not hasattr(r, "text_content"):
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/html.py in _build_doc(self)
#     783         try:
#     784             if is_url(self.io):
# --> 785                 with get_handle(
#     786                     self.io, "r", storage_options=self.storage_options
#     787                 ) as f:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     726
#     727     # open URLs
# --> 728     ioargs = _get_filepath_or_buffer(
#     729         path_or_buf,
#     730         encoding=encoding,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     382         # assuming storage_options is to be interpreted as headers
#     383         req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 384         with urlopen(req_info) as req:
#     385             content_encoding = req.headers.get("Content-Encoding", None)
#     386             if content_encoding == "gzip":
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     287     import urllib.request
#     288
# --> 289     return urllib.request.urlopen(*args, **kwargs)
#     290
#     291
#
# /usr/lib/python3.13/urllib/request.py in urlopen(url, data, timeout, context)
#     187     else:
#     188         opener = _opener
# --> 189     return opener.open(url, data, timeout)
#     190
#     191 def install_opener(opener):
#
# /usr/lib/python3.13/urllib/request.py in open(self, fullurl, data, timeout)
#     493         for processor in self.process_response.get(protocol, []):
#     494             meth = getattr(processor, meth_name)
# --> 495             response = meth(req, response)
#     496
#     497         return response
#
# /usr/lib/python3.13/urllib/request.py in http_response(self, request, response)
#     602         # request was successfully received, understood, and accepted.
#     603         if not (200 <= code < 300):
# --> 604             response = self.parent.error(
#     605                 'http', request, response, code, msg, hdrs)
#     606
#
# /usr/lib/python3.13/urllib/request.py in error(self, proto, *args)
#     531         if http_err:
#     532             args = (dict, 'default', 'http_error_default') + orig_args
# --> 533             return self._call_chain(*args)
#     534
#     535 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.13/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     464         for handler in handlers:
#     465             func = getattr(handler, meth_name)
# --> 466             result = func(*args)
#     467             if result is not None:
#     468                 return result
#
# /usr/lib/python3.13/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     611 class HTTPDefaultErrorHandler(BaseHandler):
#     612     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 613         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     614
#     615 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %% [markdown]
# Find a string method that we did not go over in class to use on your string. You can also find a list of string methods by checking the [documentation]( https://docs.python.org/3.10/library/stdtypes.html#string-methods ).

# %%
politicans = ("obama","trump","biden","trump")
print(politicans)
